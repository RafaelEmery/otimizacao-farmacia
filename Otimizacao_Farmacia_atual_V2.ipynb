# %% [markdown]
# <h2>Cálculo da solução ótima</h2>
# <br>
# <br>
# Através da curva ABC, iremos trabalhar com <strong>20% dos produtos</strong> da farmácia que representam cerca de <strong>80% da soma total anual</strong> dos remédios da farmácia.<br>
# Dito isso, nossa amostra serão os produtos das linhas <strong>1 a 562.</strong> Com a quantidade de linhas de 2118.

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pulp
# Out:
# Requirement already satisfied: pulp in /srv/conda/lib/python3.6/site-packages (1.6.10)
# Requirement already satisfied: pyparsing>=2.0.1 in /srv/conda/lib/python3.6/site-packages (from pulp) (2.4.0)

# %%
#Bibliotecas
import pandas as pd
from pulp import *

# %%
#Entrando com a tabela
dados = pd.read_csv("dados_Farmacia - Teste.csv").head(562)
dados
# Out:
#                                              DESCRICAO  \
# 0                   CITRATO DE SILDENAFILA  50MG  COMP
# 1                     TORSILAX  C/ 10 COMPR. NEO QUIM.
# 2                                   NEOSALDINA 30 DRAG
# 3                     CIMELIDE C/12 COMPR.(NIMESULIDA)
# 4                                              DORFLEX
# 5                     MELOXICAM 15 MG.C/10 COMP. MERCK
# 6                               CITRATO DE SILDENAFILA
# 7                                            MULTIGRIP
# 8                                              FLORENT
# 9                                            BETRICORT
# 10                    BUSCOPAN COMPOSTO COMP.REVESTIDO
# 11                                             NEOSORO
# 12             ALBENDAZOL 400MG 5 CPS / GEN ALBENDAZOL
# 13                                          TADALAFILA
# 14                                     DIAD 0,75MG C/2
# 15                            LOSARTANA POTASSICA 50MG
# 16                                           CIMEGRIPE
# 17                                           ACICLOVIR
# 18                                               SODIX
# 19                                       TYLENOL SINUS
# 20                                SELOZOK 50MG 30 COMP
# 21                                    NEOLEFRIN 20COMP
# 22                           PARACETAMOL 750MG 12 COMP
# 23                                            BENEGRIP
# 24                                              TREZOR
# 25                                   DIANE 35 DRG 3X21
# 26                                          IBUPROFENO
# 27                                    EXPEC XPE 120 ML
# 28   LAVITAN SUPLEMENTOS FR 60 DRG - LOTE: 1308839 ...
# 29                                             LORITIL
# ..                                                 ...
# 532                                  NORDETTE 150/30MG
# 533   AP PRESTOBARBA ULTRA GRIPE FIXO AZUL 2UN (10-UN)
# 534                              SIMETICONA GOTAS 15ML
# 535                    NOVAMOX 2X  70 ML  400 MG/57 MG
# 536                                        DIURIX 25MG
# 537                                            PROFLOX
# 538                     ACEBROFILINA ADULTO 120ML EURO
# 539                    NEUTROFER GOTAS 30 ML 250 MG/ML
# 540                                           PLENANCE
# 541                                             TROK G
# 542                         ACETILCISTEINA 600MG 16ENV
# 543                                     AFRIN PED 20ML
# 544                               DOLAMIN FLEX 12 COMP
# 545                                CIXIN 0,5MG 20 COMP
# 546                                       CALOTRAT 5ML
# 547                      PREDSIM 15 MG. 5 ML SOL.60 ML
# 548                                      STILL COLIRIO
# 549                         MUCOXOLAN XPE ADULTO 120ML
# 550                                          NISTATINA
# 551                                 GASTROL PAST C/20.
# 552                                         SIMETICONA
# 553                                           NISOFLAN
# 554               VOXX 100% PRO WHEY SAC 900G SBR CHOC
# 555                                            ANCORON
# 556                                             ANADOR
# 557                                   NAPROXENO SODICO
# 558                                     TEFIN CREME 1%
# 559                                           FLUCANIL
# 560                             TADALAFILA 20MG 2 COMP
# 561                          BRONCHO VAXOM 7MG 30 CAPS
#
#                           APRESENTACAO  QUANTIDADE  TOTAL_BRUTO TOTAL_LIQUIDO  \
# 0                   50mg cx 8 comp rev         100  12426,60019   6213,210075
# 1                        CX/ 30 COMPR.         886   10289,3602   5178,870199
# 2                                  NaN         315  9293,980021    7436,83013
# 3                     NIMESULIDA CIMED         497  7971,510023   4008,039969
# 4    300+35+50 mg comp x 300 emb. mult          51  7811,520081   4922,370056
# 5                       GENERICO MERCK         134  4978,990086   2510,040016
# 6                       50mg cx 4 comp         196  4653,140087   3124,250049
# 7               400+4+4mg 2bl x 10 cap         198  4108,739998   2059,699992
# 8                      100MG CX 12 CAP         104  3844,139931   1964,170044
# 9                         creme bg 30g         145  3826,599955   1915,829967
# 10                COMPR REV C/2BL X 10         267  3816,709995   3113,149964
# 11                               30 ML         426  3644,110103   1847,560015
# 12                                 NaN         119  3617,650055   1854,110028
# 13      20mg cx 60 comp rev (Emb Frac)           4   3412,77002   1706,400024
# 14                          0,75MG C/2         187  2956,979963   1506,079982
# 15                                50MG         306  2919,239988   1754,419991
# 16                400+4+4mg cx 100 cap          29  2864,329903   1091,449989
# 17                    200mg fr 25 comp          27  2805,060036   1402,530018
# 18                 50mg cx 20 comp rev         260  2607,969925   1303,969962
# 19                          COMPRIMIDO         156   2592,75001   2084,679992
# 20                         50MG 30COMP          45  2481,499958   1998,950043
# 21           400+20+400+4mg cx 20 comp         144  2384,579945   1207,939976
# 22                       750MG 12 COMP          15  2359,379913   1180,249957
# 23                6 COMPRIMIDOS                259  2327,449978   1657,349997
# 24                 10mg cx 30 comp rev          46  2272,199982   1826,080032
# 25                                 NaN          37  2219,200039   1775,410042
# 26          100mg/ml susp oral fr 20ml         114  2046,300087   1050,629951
# 27                   VD.120 ML LEGRAND          64  2022,870005    1011,49998
# 28                                 NaN          49         1960          1240
# 29                     10MG CX 12 COMP         122  1934,719973   983,3199787
# ..                                 ...         ...          ...           ...
# 532         3 BLISTERES COM 21 DRAGEAS           9  231,1199989   184,8899994
# 533                                NaN           4  230,8000031   178,8799973
# 534             75mg emul oral fr 15ml          27  230,0999937   130,3299956
# 535                    70 ML400MG/57MG           4          230           184
# 536                     30 COMPRIMIDOS          61   229,679996   201,6799965
# 537                   500MG FR 14 COMP           4  229,1800003   183,3300018
# 538           10mg/ml xpe fr 120ml +cm           8  229,0399933   114,4800034
# 539                 250 MG.GOTAS 30 ML           5  228,8100014   187,5500069
# 540                10mg cx 90 comp rev           2       228,25   182,5999985
# 541                                30G          10  227,9000092   182,2999954
# 542               600mg cx 16 env x 5g           5  227,7499962   113,8500023
# 543                        fr 20ml ped          16  227,3399935   178,9699993
# 544           125+5,0mg cx 12 comp rev           6  227,1600037   189,4699993
# 545                   0,5mg cx 20 comp           9  227,0699978   121,3599997
# 546                            LIQUIDO           9  226,0800076   113,0400038
# 547                    60 ML=15 MG/5ML           9  225,6599979   180,5400066
# 548                            COLIRIO          15  225,6299992         183,5
# 549            6mg/ml xpe fr 120ml adu          11        225,5           123
# 550       100mui/ml sus or fr cgt 50ml          10  225,2000046   112,6000023
# 551                   LUPER C/20 PAST.          23  222,1999969   115,1999984
# 552                    40mg cx 20 comp          17  221,1800051   115,7000031
# 553                   100MG CX 12 COMP          17          221         122,5
# 554                                NaN           4          220           220
# 555               200mg cx 30 comp rev           5  219,7999954   175,8499908
# 556        500mg cx 240bl x 4 comp e.m           1  219,3600006   164,5200043
# 557               550mg cx 10 comp rev          12   218,519989   114,7599974
# 558                                20G           8   218,489996   163,8900051
# 559                     150mg cx 2 cap          13  217,7999916   108,8999958
# 560                 20mg cx 2 comp rev           6  217,5399933   108,7900009
# 561          7mg po liof cx 30 cap gel           1        217,5           165
#
#     PROD_SALDO VALOR_ULT_COMPRA
# 0            4       4,10529995
# 1          -12      2,290888786
# 2           13      22,23749924
# 3           71      2,524600029
# 4            1      117,3399963
# 5            5      6,454999924
# 6           49      3,319999933
# 7           33      4,289999962
# 8            6      12,18875027
# 9           17      5,309999943
# 10         -18      10,76329994
# 11          54      2,319999933
# 12          45      7,324399948
# 13           1      104,8700027
# 14          65      2,549999952
# 15          35      2,487499952
# 16          21      12,48999977
# 17           8      17,29000092
# 18          98      2,339999914
# 19          22      12,78999996
# 20           3      42,72999954
# 21          12      4,829999924
# 22          12      43,25999832
# 23          40      6,684400082
# 24           2      29,04999924
# 25           3      45,11000061
# 26          60      2,789999962
# 27          29      8,616200447
# 28          31      8,989999771
# 29          34      2,493299961
# ..         ...              ...
# 532          1      19,61000061
# 533          3      43,04999924
# 534          3      2,416699886
# 535          2      41,17499924
# 536         22      0,959999979
# 537          1      42,77999878
# 538          0      8,449999809
# 539          2      36,38999939
# 540          0      81,76999664
# 541          7      17,84000015
# 542          0      15,22000027
# 543          1      10,64000034
# 544          1      29,12999916
# 545          0      5,840000153
# 546          9      9,880000114
# 547          6      18,71999931
# 548          4            10,75
# 549          1      3,390000105
# 550          4      6,086699963
# 551         -4      3,910000086
# 552          1       2,50999999
# 553         53      2,130000114
# 554          2               46
# 555          0      30,85000038
# 556          3      156,3399963
# 557          0       5,97329998
# 558          1      20,42000008
# 559          3      2,265799999
# 560          0      4,626699924
# 561          0      157,3300018
#
# [562 rows x 7 columns]

# %%
limite = 562

# %%
#Esse vetor possui todos os valores (TOTAL_BRUTO) dos produtos pertencentes a classe A
#Os valores desse vetor posteriormente vão ser trabalhados
valorClasseA = []
for index,item in enumerate(dados.TOTAL_BRUTO):
    if(',' in item):
        lista_modifica_string = list(item)
        index_virgula = lista_modifica_string.index(',')
        lista_modifica_string[index_virgula] = '.'
        new_string = "".join(lista_modifica_string)
    else:
        new_string = item
    if (index < limite):
        valorClasseA.insert(index,float(new_string))
    else:
        break

# %%
#Esse vetor possui todos os valores (QUANTIDADE) dos produtos pertencentes a classe A
#Os valores desse vetor posteriormente vão ser trabalhados
quantidadeClasseA = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        quantidadeClasseA.insert(index,item)
    else:
        break

# %%
quantidadeClasseA
# Out:
# [100,
#  886,
#  315,
#  497,
#  51,
#  134,
#  196,
#  198,
#  104,
#  145,
#  267,
#  426,
#  119,
#  4,
#  187,
#  306,
#  29,
#  27,
#  260,
#  156,
#  45,
#  144,
#  15,
#  259,
#  46,
#  37,
#  114,
#  64,
#  49,
#  122,
#  15,
#  26,
#  73,
#  36,
#  111,
#  52,
#  49,
#  8,
#  85,
#  9,
#  18,
#  27,
#  33,
#  14,
#  65,
#  295,
#  27,
#  45,
#  104,
#  86,
#  18,
#  205,
#  19,
#  69,
#  90,
#  46,
#  5,
#  39,
#  48,
#  17,
#  131,
#  64,
#  44,
#  126,
#  177,
#  38,
#  111,
#  19,
#  25,
#  25,
#  10,
#  52,
#  22,
#  49,
#  11,
#  4,
#  72,
#  45,
#  15,
#  36,
#  52,
#  1147,
#  52,
#  13,
#  9,
#  456,
#  93,
#  5,
#  16,
#  34,
#  40,
#  4,
#  58,
#  13,
#  77,
#  18,
#  13,
#  24,
#  225,
#  62,
#  38,
#  31,
#  36,
#  302,
#  35,
#  14,
#  49,
#  29,
#  17,
#  7,
#  14,
#  45,
#  43,
#  28,
#  14,
#  6,
#  71,
#  23,
#  17,
#  73,
#  19,
#  7,
#  10,
#  7,
#  21,
#  36,
#  6,
#  7,
#  21,
#  23,
#  224,
#  16,
#  416,
#  24,
#  15,
#  48,
#  41,
#  9,
#  39,
#  7,
#  8,
#  9,
#  107,
#  24,
#  45,
#  8,
#  56,
#  17,
#  12,
#  12,
#  19,
#  6,
#  38,
#  63,
#  41,
#  33,
#  9,
#  33,
#  6,
#  26,
#  92,
#  39,
#  46,
#  45,
#  33,
#  25,
#  49,
#  75,
#  5,
#  3,
#  315,
#  14,
#  34,
#  38,
#  132,
#  7,
#  39,
#  57,
#  6,
#  10,
#  18,
#  10,
#  19,
#  65,
#  29,
#  9,
#  25,
#  41,
#  53,
#  39,
#  29,
#  6,
#  8,
#  7,
#  27,
#  7,
#  4,
#  17,
#  24,
#  21,
#  38,
#  39,
#  10,
#  21,
#  15,
#  21,
#  127,
#  21,
#  23,
#  7,
#  30,
#  26,
#  12,
#  17,
#  61,
#  19,
#  13,
#  60,
#  23,
#  31,
#  19,
#  3,
#  9,
#  35,
#  12,
#  33,
#  8,
#  11,
#  20,
#  83,
#  4,
#  10,
#  24,
#  22,
#  20,
#  65,
#  35,
#  10,
#  7,
#  22,
#  15,
#  8,
#  7,
#  27,
#  30,
#  8,
#  18,
#  21,
#  19,
#  500,
#  19,
#  10,
#  62,
#  17,
#  33,
#  17,
#  30,
#  24,
#  81,
#  13,
#  18,
#  51,
#  21,
#  25,
#  15,
#  16,
#  19,
#  36,
#  13,
#  6,
#  28,
#  66,
#  10,
#  25,
#  8,
#  10,
#  16,
#  14,
#  29,
#  1,
#  8,
#  12,
#  8,
#  12,
#  14,
#  10,
#  13,
#  3,
#  27,
#  30,
#  6,
#  7,
#  20,
#  3,
#  7,
#  8,
#  18,
#  9,
#  7,
#  13,
#  22,
#  13,
#  6,
#  3,
#  87,
#  22,
#  7,
#  14,
#  15,
#  13,
#  23,
#  18,
#  4,
#  6,
#  8,
#  6,
#  6,
#  48,
#  13,
#  14,
#  27,
#  11,
#  12,
#  6,
#  19,
#  22,
#  15,
#  37,
#  21,
#  23,
#  39,
#  14,
#  20,
#  15,
#  4,
#  18,
#  3,
#  12,
#  14,
#  23,
#  10,
#  27,
#  9,
#  29,
#  14,
#  7,
#  24,
#  6,
#  17,
#  13,
#  13,
#  4,
#  3,
#  29,
#  22,
#  7,
#  19,
#  5,
#  9,
#  7,
#  8,
#  8,
#  26,
#  3,
#  19,
#  9,
#  5,
#  6,
#  7,
#  28,
#  6,
#  2,
#  11,
#  103,
#  14,
#  23,
#  4,
#  6,
#  9,
#  6,
#  4,
#  17,
#  7,
#  4,
#  16,
#  3,
#  6,
#  11,
#  33,
#  6,
#  5,
#  10,
#  11,
#  220,
#  4,
#  16,
#  21,
#  6,
#  7,
#  14,
#  13,
#  6,
#  19,
#  25,
#  62,
#  7,
#  3,
#  6,
#  35,
#  17,
#  8,
#  7,
#  9,
#  11,
#  9,
#  33,
#  9,
#  17,
#  9,
#  11,
#  4,
#  17,
#  3,
#  3,
#  12,
#  12,
#  3,
#  4,
#  2,
#  2,
#  32,
#  15,
#  7,
#  149,
#  1,
#  10,
#  7,
#  5,
#  1,
#  22,
#  12,
#  5,
#  9,
#  8,
#  10,
#  7,
#  12,
#  24,
#  15,
#  1,
#  13,
#  6,
#  5,
#  10,
#  6,
#  5,
#  12,
#  15,
#  19,
#  3,
#  5,
#  23,
#  3,
#  11,
#  92,
#  3,
#  3,
#  8,
#  30,
#  51,
#  6,
#  8,
#  5,
#  7,
#  11,
#  17,
#  3,
#  5,
#  6,
#  2,
#  12,
#  4,
#  9,
#  14,
#  14,
#  3,
#  10,
#  4,
#  5,
#  15,
#  9,
#  3,
#  16,
#  27,
#  16,
#  5,
#  13,
#  16,
#  12,
#  6,
#  4,
#  12,
#  21,
#  14,
#  2,
#  7,
#  7,
#  10,
#  10,
#  9,
#  4,
#  2,
#  6,
#  17,
#  61,
#  7,
#  14,
#  12,
#  7,
#  11,
#  11,
#  121,
#  9,
#  4,
#  15,
#  9,
#  6,
#  5,
#  4,
#  35,
#  7,
#  8,
#  9,
#  4,
#  27,
#  4,
#  61,
#  4,
#  8,
#  5,
#  2,
#  10,
#  5,
#  16,
#  6,
#  9,
#  9,
#  9,
#  15,
#  11,
#  10,
#  23,
#  17,
#  17,
#  4,
#  5,
#  1,
#  12,
#  8,
#  13,
#  6,
#  1]

# %%
mediaVenda = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        media = quantidadeClasseA[index] / 12
        mediaVenda.insert(index,media)
    else:
        break

# %%
mediaVenda
# Out:
# [8.333333333333334,
#  73.83333333333333,
#  26.25,
#  41.416666666666664,
#  4.25,
#  11.166666666666666,
#  16.333333333333332,
#  16.5,
#  8.666666666666666,
#  12.083333333333334,
#  22.25,
#  35.5,
#  9.916666666666666,
#  0.3333333333333333,
#  15.583333333333334,
#  25.5,
#  2.4166666666666665,
#  2.25,
#  21.666666666666668,
#  13.0]

# %%
lucro = []
for index,item in enumerate(dados.TOTAL_LIQUIDO):
    if(',' in item):
        lista_modifica_string = list(item)
        index_virgula = lista_modifica_string.index(',')
        lista_modifica_string[index_virgula] = '.'
        new_string = "".join(lista_modifica_string)
    else:
        new_string = item
    if (index < limite):
        lucro.insert(index, float(new_string)/quantidadeClasseA[index])
    else:
        break

# %%
lucro[0:20]
# Out:
# [62.13210075,
#  5.845225958239277,
#  23.60898453968254,
#  8.064466738430584,
#  96.51705992156862,
#  18.73164191044776,
#  15.940051270408164,
#  10.402525212121212,
#  18.886250423076923,
#  13.212620462068966,
#  11.659737692883896,
#  4.336995340375587,
#  15.580756537815127,
#  426.600006,
#  8.053903647058823,
#  5.733398663398693,
#  37.636206517241376,
#  51.94555622222222,
#  5.015269084615384,
#  13.363333282051281]

# %%
desvioPadrao = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        desvioPadrao.insert(index, mediaVenda[index] * 0.1)
    else:
        break

# %%
vendaMinima = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        vendaMinima.insert(index, (mediaVenda[index] - desvioPadrao[index]))
    else:
        break

# %%
vendaMaxima = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        vendaMaxima.insert(index, (mediaVenda[index] + desvioPadrao[index]))
    else:
        break

# %%
giroEstoque = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        giroEstoque.insert(index, float(item)/(float(item) + float(dados.PROD_SALDO[index])))
    else:
        break

# %%
custoUnitario = []
for index,item in enumerate(dados.TOTAL_LIQUIDO):
    if(',' in item):
        lista_modifica_string = list(item)
        index_virgula = lista_modifica_string.index(',')
        lista_modifica_string[index_virgula] = '.'
        new_string = "".join(lista_modifica_string)
    else:
        new_string = item
    if (index < limite):
        custoUnitario.insert(index, (valorClasseA[index]-float(new_string))/quantidadeClasseA[index])
    else:
        break

# %%
custoUnitario[0:20]
# Out:
# [62.13390114999999,
#  5.768047405191873,
#  5.895713939682537,
#  7.974788841046277,
#  56.65000049019608,
#  18.425000522388057,
#  7.800459377551018,
#  10.3486868989899,
#  18.076633528846155,
#  13.177724055172416,
#  2.63505629588015,
#  4.21725372769953,
#  14.819664092436975,
#  426.592499,
#  7.758823427807488,
#  3.8066012973856203,
#  61.13379013793103,
#  51.94555622222222,
#  5.015384473076923,
#  3.256859089743592]

# %%
capital = 0
for index,item in enumerate(dados.TOTAL_LIQUIDO):
    if(',' in item):
        lista_modifica_string = list(item)
        index_virgula = lista_modifica_string.index(',')
        lista_modifica_string[index_virgula] = '.'
        new_string = "".join(lista_modifica_string)
    else:
        new_string = item
    if (index < limite):
        capital += valorClasseA[index]-float(new_string)
    else:
        break

# %%
capital
# Out:
# 141215.60983940001

# %%
#Cria o problema
prob = LpProblem("Maximização de lucros - Farmácia", LpMaximize)

# %%
#Cria as variáveis
xi = []
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        xi.insert(index, LpVariable("q"+str(index),0,None))
    else:
        break

# %%
obj = None
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        obj += lucro[index]*xi[index]
    else:
        break

# %%
#Função objetivo
prob += obj

# %%
#Restrições - Venda Minima
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        prob += xi[index] >= vendaMinima[index]
    else:
        break

# %%
#Restrições - Venda Maxima
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        prob += xi[index] <= float(item) + (12*desvioPadrao[index])
    else:
        break

# %%
#Restrições - Espaço
obj = None
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        obj += xi[index]
    else:
        break

# %%
prob+= obj <= 21031

# %%
prob.solve()
# Out:
# 1

# %%
#Imprimindo o status da resolucao
print("Status: ", LpStatus[prob.status])
# Out:
# Status:  Optimal

# %%
#Imprimindo os valores das variáveis
for cont in prob.variables():
    print(cont.name, " = ", cont.varValue)
# Out:
# q0  =  110.0
# q1  =  974.6
# q10  =  293.7
# q100  =  41.8
# q101  =  34.1
# q102  =  39.6
# q103  =  332.2
# q104  =  38.5
# q105  =  15.4
# q106  =  53.9
# q107  =  31.9
# q108  =  18.7
# q109  =  7.7
# q11  =  468.6
# q110  =  15.4
# q111  =  49.5
# q112  =  47.3
# q113  =  30.8
# q114  =  15.4
# q115  =  6.6
# q116  =  78.1
# q117  =  25.3
# q118  =  18.7
# q119  =  80.3
# q12  =  130.9
# q120  =  20.9
# q121  =  7.7
# q122  =  11.0
# q123  =  7.7
# q124  =  23.1
# q125  =  39.6
# q126  =  6.6
# q127  =  7.7
# q128  =  23.1
# q129  =  25.3
# q13  =  4.4
# q130  =  246.4
# q131  =  17.6
# q132  =  268.175
# q133  =  26.4
# q134  =  16.5
# q135  =  52.8
# q136  =  45.1
# q137  =  9.9
# q138  =  42.9
# q139  =  7.7
# q14  =  205.7
# q140  =  8.8
# q141  =  9.9
# q142  =  117.7
# q143  =  26.4
# q144  =  49.5
# q145  =  8.8
# q146  =  61.6
# q147  =  18.7
# q148  =  13.2
# q149  =  13.2
# q15  =  336.6
# q150  =  20.9
# q151  =  6.6
# q152  =  41.8
# q153  =  69.3
# q154  =  45.1
# q155  =  36.3
# q156  =  9.9
# q157  =  36.3
# q158  =  6.6
# q159  =  28.6
# q16  =  31.9
# q160  =  101.2
# q161  =  42.9
# q162  =  50.6
# q163  =  49.5
# q164  =  36.3
# q165  =  27.5
# q166  =  53.9
# q167  =  82.5
# q168  =  5.5
# q169  =  3.3
# q17  =  29.7
# q170  =  346.5
# q171  =  15.4
# q172  =  37.4
# q173  =  41.8
# q174  =  145.2
# q175  =  7.7
# q176  =  42.9
# q177  =  62.7
# q178  =  6.6
# q179  =  11.0
# q18  =  286.0
# q180  =  19.8
# q181  =  11.0
# q182  =  20.9
# q183  =  71.5
# q184  =  31.9
# q185  =  9.9
# q186  =  27.5
# q187  =  45.1
# q188  =  58.3
# q189  =  42.9
# q19  =  171.6
# q190  =  31.9
# q191  =  6.6
# q192  =  8.8
# q193  =  7.7
# q194  =  29.7
# q195  =  7.7
# q196  =  4.4
# q197  =  18.7
# q198  =  26.4
# q199  =  23.1
# q2  =  346.5
# q20  =  49.5
# q200  =  41.8
# q201  =  42.9
# q202  =  11.0
# q203  =  23.1
# q204  =  16.5
# q205  =  23.1
# q206  =  139.7
# q207  =  23.1
# q208  =  25.3
# q209  =  7.7
# q21  =  158.4
# q210  =  33.0
# q211  =  28.6
# q212  =  13.2
# q213  =  18.7
# q214  =  67.1
# q215  =  20.9
# q216  =  14.3
# q217  =  66.0
# q218  =  25.3
# q219  =  34.1
# q22  =  16.5
# q220  =  20.9
# q221  =  3.3
# q222  =  9.9
# q223  =  38.5
# q224  =  13.2
# q225  =  36.3
# q226  =  8.8
# q227  =  12.1
# q228  =  22.0
# q229  =  91.3
# q23  =  284.9
# q230  =  4.4
# q231  =  11.0
# q232  =  26.4
# q233  =  24.2
# q234  =  22.0
# q235  =  71.5
# q236  =  38.5
# q237  =  11.0
# q238  =  7.7
# q239  =  24.2
# q24  =  50.6
# q240  =  16.5
# q241  =  8.8
# q242  =  7.7
# q243  =  29.7
# q244  =  33.0
# q245  =  8.8
# q246  =  19.8
# q247  =  23.1
# q248  =  20.9
# q249  =  37.5
# q25  =  40.7
# q250  =  20.9
# q251  =  11.0
# q252  =  68.2
# q253  =  18.7
# q254  =  36.3
# q255  =  18.7
# q256  =  33.0
# q257  =  26.4
# q258  =  89.1
# q259  =  14.3
# q26  =  125.4
# q260  =  19.8
# q261  =  56.1
# q262  =  23.1
# q263  =  27.5
# q264  =  16.5
# q265  =  17.6
# q266  =  20.9
# q267  =  39.6
# q268  =  14.3
# q269  =  6.6
# q27  =  70.4
# q270  =  30.8
# q271  =  72.6
# q272  =  11.0
# q273  =  27.5
# q274  =  8.8
# q275  =  11.0
# q276  =  17.6
# q277  =  15.4
# q278  =  31.9
# q279  =  1.1
# q28  =  53.9
# q280  =  8.8
# q281  =  13.2
# q282  =  8.8
# q283  =  13.2
# q284  =  15.4
# q285  =  11.0
# q286  =  14.3
# q287  =  3.3
# q288  =  29.7
# q289  =  33.0
# q29  =  134.2
# q290  =  6.6
# q291  =  7.7
# q292  =  22.0
# q293  =  3.3
# q294  =  7.7
# q295  =  8.8
# q296  =  19.8
# q297  =  9.9
# q298  =  7.7
# q299  =  14.3
# q3  =  546.7
# q30  =  16.5
# q300  =  24.2
# q301  =  14.3
# q302  =  6.6
# q303  =  3.3
# q304  =  95.7
# q305  =  24.2
# q306  =  7.7
# q307  =  15.4
# q308  =  16.5
# q309  =  14.3
# q31  =  28.6
# q310  =  25.3
# q311  =  19.8
# q312  =  4.4
# q313  =  6.6
# q314  =  8.8
# q315  =  6.6
# q316  =  6.6
# q317  =  52.8
# q318  =  14.3
# q319  =  15.4
# q32  =  80.3
# q320  =  29.7
# q321  =  12.1
# q322  =  13.2
# q323  =  6.6
# q324  =  20.9
# q325  =  24.2
# q326  =  16.5
# q327  =  40.7
# q328  =  23.1
# q329  =  25.3
# q33  =  39.6
# q330  =  42.9
# q331  =  15.4
# q332  =  22.0
# q333  =  16.5
# q334  =  4.4
# q335  =  19.8
# q336  =  3.3
# q337  =  13.2
# q338  =  15.4
# q339  =  25.3
# q34  =  122.1
# q340  =  11.0
# q341  =  29.7
# q342  =  9.9
# q343  =  31.9
# q344  =  15.4
# q345  =  7.7
# q346  =  26.4
# q347  =  6.6
# q348  =  18.7
# q349  =  14.3
# q35  =  57.2
# q350  =  14.3
# q351  =  4.4
# q352  =  3.3
# q353  =  31.9
# q354  =  24.2
# q355  =  7.7
# q356  =  20.9
# q357  =  5.5
# q358  =  9.9
# q359  =  7.7
# q36  =  53.9
# q360  =  8.8
# q361  =  8.8
# q362  =  28.6
# q363  =  3.3
# q364  =  20.9
# q365  =  9.9
# q366  =  5.5
# q367  =  6.6
# q368  =  7.7
# q369  =  30.8
# q37  =  8.8
# q370  =  6.6
# q371  =  2.2
# q372  =  12.1
# q373  =  113.3
# q374  =  15.4
# q375  =  25.3
# q376  =  4.4
# q377  =  6.6
# q378  =  9.9
# q379  =  6.6
# q38  =  93.5
# q380  =  4.4
# q381  =  18.7
# q382  =  7.7
# q383  =  4.4
# q384  =  17.6
# q385  =  3.3
# q386  =  6.6
# q387  =  12.1
# q388  =  36.3
# q389  =  6.6
# q39  =  9.9
# q390  =  5.5
# q391  =  11.0
# q392  =  12.1
# q393  =  16.5
# q394  =  4.4
# q395  =  17.6
# q396  =  23.1
# q397  =  6.6
# q398  =  7.7
# q399  =  15.4
# q4  =  56.1
# q40  =  19.8
# q400  =  14.3
# q401  =  6.6
# q402  =  20.9
# q403  =  27.5
# q404  =  68.2
# q405  =  7.7
# q406  =  3.3
# q407  =  6.6
# q408  =  38.5
# q409  =  18.7
# q41  =  29.7
# q410  =  8.8
# q411  =  7.7
# q412  =  9.9
# q413  =  12.1
# q414  =  9.9
# q415  =  36.3
# q416  =  9.9
# q417  =  18.7
# q418  =  9.9
# q419  =  12.1
# q42  =  36.3
# q420  =  4.4
# q421  =  18.7
# q422  =  3.3
# q423  =  3.3
# q424  =  13.2
# q425  =  13.2
# q426  =  3.3
# q427  =  4.4
# q428  =  2.2
# q429  =  2.2
# q43  =  15.4
# q430  =  35.2
# q431  =  16.5
# q432  =  7.7
# q433  =  163.9
# q434  =  1.1
# q435  =  11.0
# q436  =  7.7
# q437  =  5.5
# q438  =  1.1
# q439  =  24.2
# q44  =  71.5
# q440  =  13.2
# q441  =  5.5
# q442  =  9.9
# q443  =  8.8
# q444  =  11.0
# q445  =  7.7
# q446  =  13.2
# q447  =  26.4
# q448  =  16.5
# q449  =  1.1
# q45  =  324.5
# q450  =  14.3
# q451  =  6.6
# q452  =  5.5
# q453  =  11.0
# q454  =  6.6
# q455  =  5.5
# q456  =  13.2
# q457  =  16.5
# q458  =  20.9
# q459  =  3.3
# q46  =  29.7
# q460  =  5.5
# q461  =  25.3
# q462  =  3.3
# q463  =  12.1
# q464  =  101.2
# q465  =  3.3
# q466  =  3.3
# q467  =  8.8
# q468  =  33.0
# q469  =  56.1
# q47  =  49.5
# q470  =  6.6
# q471  =  8.8
# q472  =  5.5
# q473  =  7.7
# q474  =  12.1
# q475  =  18.7
# q476  =  3.3
# q477  =  5.5
# q478  =  6.6
# q479  =  2.2
# q48  =  114.4
# q480  =  13.2
# q481  =  4.4
# q482  =  9.9
# q483  =  15.4
# q484  =  15.4
# q485  =  3.3
# q486  =  11.0
# q487  =  4.4
# q488  =  5.5
# q489  =  16.5
# q49  =  94.6
# q490  =  9.9
# q491  =  3.3
# q492  =  17.6
# q493  =  29.7
# q494  =  17.6
# q495  =  5.5
# q496  =  14.3
# q497  =  17.6
# q498  =  13.2
# q499  =  6.6
# q5  =  147.4
# q50  =  19.8
# q500  =  4.4
# q501  =  13.2
# q502  =  23.1
# q503  =  15.4
# q504  =  2.2
# q505  =  7.7
# q506  =  7.7
# q507  =  11.0
# q508  =  11.0
# q509  =  9.9
# q51  =  225.5
# q510  =  4.4
# q511  =  2.2
# q512  =  6.6
# q513  =  18.7
# q514  =  67.1
# q515  =  7.7
# q516  =  15.4
# q517  =  13.2
# q518  =  7.7
# q519  =  12.1
# q52  =  20.9
# q520  =  12.1
# q521  =  133.1
# q522  =  9.9
# q523  =  4.4
# q524  =  16.5
# q525  =  9.9
# q526  =  6.6
# q527  =  5.5
# q528  =  4.4
# q529  =  38.5
# q53  =  75.9
# q530  =  7.7
# q531  =  8.8
# q532  =  9.9
# q533  =  4.4
# q534  =  29.7
# q535  =  4.4
# q536  =  67.1
# q537  =  4.4
# q538  =  8.8
# q539  =  5.5
# q54  =  99.0
# q540  =  2.2
# q541  =  11.0
# q542  =  5.5
# q543  =  17.6
# q544  =  6.6
# q545  =  9.9
# q546  =  9.9
# q547  =  9.9
# q548  =  16.5
# q549  =  12.1
# q55  =  50.6
# q550  =  11.0
# q551  =  25.3
# q552  =  18.7
# q553  =  18.7
# q554  =  4.4
# q555  =  5.5
# q556  =  1.1
# q557  =  13.2
# q558  =  8.8
# q559  =  14.3
# q56  =  5.5
# q560  =  6.6
# q561  =  1.1
# q57  =  42.9
# q58  =  52.8
# q59  =  18.7
# q6  =  215.6
# q60  =  144.1
# q61  =  70.4
# q62  =  48.4
# q63  =  138.6
# q64  =  194.7
# q65  =  41.8
# q66  =  122.1
# q67  =  20.9
# q68  =  27.5
# q69  =  27.5
# q7  =  217.8
# q70  =  11.0
# q71  =  57.2
# q72  =  24.2
# q73  =  53.9
# q74  =  12.1
# q75  =  4.4
# q76  =  79.2
# q77  =  49.5
# q78  =  16.5
# q79  =  39.6
# q8  =  114.4
# q80  =  57.2
# q81  =  86.025
# q82  =  57.2
# q83  =  14.3
# q84  =  9.9
# q85  =  501.6
# q86  =  102.3
# q87  =  5.5
# q88  =  17.6
# q89  =  37.4
# q9  =  159.5
# q90  =  44.0
# q91  =  4.4
# q92  =  63.8
# q93  =  14.3
# q94  =  84.7
# q95  =  19.8
# q96  =  14.3
# q97  =  26.4
# q98  =  247.5
# q99  =  68.2

# %%
custo = 0
#Calculo Custo Total
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        custo += custoUnitario[index]*prob.variables()[index].varValue
    else:
        break
print(custo)
# Out:
# 465320.7912558254

# %%
custo = 0
#Calculo Custo Total
for index,item in enumerate(dados.QUANTIDADE):
    if (index < limite):
        custo += prob.variables()[index].varValue
    else:
        break
print(custo)
# Out:
# 21031.00000000001

# %%
#Imprimindo o valor do custo total
print("Lucro total: ", value(prob.objective))
# Out:
# Lucro total:  310013.84255884937
